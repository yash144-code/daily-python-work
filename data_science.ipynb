# %% [markdown]
# <a href="https://colab.research.google.com/github/yash144-code/daily-python-work/blob/main/data_science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Let's learn pyhon from nothing to everything**

# %% [markdown]
# **DAY 1:**

# %% [markdown]
# 1. A Hello World program

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# 2. program for adding two numbers

# %%
a= 2
b= 5
print("sum of a and b:",a+b)
# Out:
# sum of a and b: 7

# %% [markdown]
# **DAY 2:**

# %% [markdown]
# 3. writing identifiers

# %% [markdown]
# **# POINT 1:**
#
# While writing an identifier we can use,
#   1. Alphabets, either upper case or lower case
#   2. Numbers from 0 to 9
#   3. Underscore symbol ( _ )
#
# If we are using any other symbol then we will get syntax error.

# %%
student_id = 629
print(student_id)
# Out:
# 629

# %%
Student_ID = 585
print(Student_ID)
# Out:
# 585

# %% [markdown]
# **#POINT 2:**
#
# We can write an identifier with number but identifier should not start
# with digit.
# EXAMPLE :
#
# student_name1= "yash"  ✅
# 1student_name= "yash"  ❎

# %%
student_name1="yash"
print(student_name1)
# Out:
# yash

# %%
example12=12,15,'name',"age"
print(example12)
# Out:
# (12, 15, 'name', 'age')

# %% [markdown]
# **# POINT 3:**
# Identifiers are case sesitive
# EXAMPLE:
# value = 10
# print(VALUE)    ❎   shows syntax error

# %%
value=20
print(value)
# Out:
# 20

# %%
VALUE=25
print(VALUE)
# Out:
# 25

# %% [markdown]
# **# point4:**
# We cannot use keywords as identifiers.
# import = 21
# print(import)  ❌  It throws a syntax error
#
# **# point 5:**
# Spaces are not allowed in between the identifier

# %%
important = 25
print(important)
# Out:
# 25

# %% [markdown]
# **DAY 5:**

# %%
inter=100
print('inter',inter)
# Out:
# inter 100

# %%
throw= 100
print(throw)
# Out:
# 100

# %% [markdown]
# **single line and multi line comments**

# %%
name = "yash"
#we have too use quotes to print a string
print(name)
# Out:
# yash

# %%
yash= "name"
"""we have to use triple quotes
as multi line comments
the quotes should double quoted or single quoted"""
yash = 21
print(yash)
# Out:
# 21

# %%
print ("hello")
"""hello
whats happening"""
# Out:
# hello
# 'hello\nwhats happening'

# %% [markdown]
# **Variables**

# %%
Name_Of_The_variable= "yash"
print(Name_Of_The_variable)
# Out:
# yash

# %%
X = 20
print(X)
# Out:
# 20

# %% [markdown]
# **DAY 6:**
# printing different kinds of variables

# %%
name="yash"
age = 21
marks =88
percentage=88.0
anything = None
print(name,age,marks,percentage)
print(type(name))
print(type(age))
print(type(marks))
print(type(percentage))
print(type(anything))
# Out:
# yash 21 88 88.0
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'NoneType'>

# %% [markdown]
# **SET{}**

# %% [markdown]
# ### Sets: Uniqueness
# One key thing to remember about sets is that they only store unique elements. If you try to add a duplicate element to a set, it will be ignored.

# %%
my_set = {1, 2, 3, 2, 1}
print(my_set) # Output will be {1, 2, 3}
# Out:
# {1, 2, 3}

# %%
Student={"sai","yash","venky","tharun"}
print(Student)
print(type(Student))
# Out:
# {'sai', 'yash', 'tharun', 'venky'}
# <class 'set'>

# %%
marks={10,20,30,40}
print(marks)
print(type(marks))
# Out:
# {40, 10, 20, 30}
# <class 'set'>

# %% [markdown]
# **LIST[]**

# %% [markdown]
# ### Lists: Mutability
# Lists are mutable, which means you can change their elements after creation. You can add, remove, or modify elements in a list.

# %%
Student=["sai","yash","venky","tharun"]
print(Student)
print(type(Student))
# Out:
# ['sai', 'yash', 'venky', 'tharun']
# <class 'list'>

# %%
my_list = [1, 2, 3]
my_list.append(4)
my_list[0] = 10
print(my_list)
# Out:
# [10, 2, 3, 4]

# %%
my_num=[10,20,30,40]
my_num.append(50)
print(my_num)
print("-----------------------------")
my_num[0]=100
print(my_num)
print("----------------------------")
my_num.append(60)
print(my_num)
# Out:
# [10, 20, 30, 40, 50]
# -----------------------------
# [100, 20, 30, 40, 50]
# ----------------------------
# [100, 20, 30, 40, 50, 60]

# %% [markdown]
# **TUPLE()**

# %% [markdown]
# ### Tuples: Immutability
# Tuples are immutable, meaning you cannot change their elements after they are created. This makes them useful for storing data that should not be modified.

# %%
Student=("sai","yash","venky","tharun")
print(Student)
print(type(Student))
# Out:
# ('sai', 'yash', 'venky', 'tharun')
# <class 'tuple'>

# %%
my_tuple = (1, 2, 3)
# The following line would cause an error:
#my_tuple[0] = 10
print(my_tuple)
# Out:
# (1, 2, 3)

# %% [markdown]
# **DICT{key:value}**

# %% [markdown]
# ### Dictionaries: Key-Value Pairs
# Dictionaries store data in key-value pairs. Each key must be unique, and it maps to a specific value. You can access values using their corresponding keys.

# %%
name_id= {"yash":629,"sai":622,"shiva":608,"vyas":619}
print(name_id)
print(type(name_id))
# Out:
# {'yash': 629, 'sai': 622, 'shiva': 608, 'vyas': 619}
# <class 'dict'>

# %%
my_dict = {"apple": 1, "banana": 2, "cherry": 3}
print(my_dict["banana"]) # Output will be 2
my_dict["date"] = 4 # Add a new key-value pair
print(my_dict)
# Out:
# 2
# {'apple': 1, 'banana': 2, 'cherry': 3, 'date': 4}

# %%
marks = {"yash":30,"sai":33,"vyas":25,"shiva":26,"srikar":33,"vishnu":29,"venky":25}
print(marks["venky"])
# Out:
# 25

# %%
marks = {"yash":30,"sai":33,"vyas":25,"shiva":26,"srikar":33,"vishnu":29,"venky":25}

students_with_25_marks = []
for name, mark in marks.items():
  if mark == 25:
    students_with_25_marks.append(name)

print("Students with 25 marks:", students_with_25_marks)
# Out:
# Students with 25 marks: ['vyas', 'venky']

# %%
marks = {"yash":30,"sai":33,"vyas":25,"shiva":26,"srikar":33,"vishnu":29,"venky":25}
students_with_26_marks = []
for name, value in marks.items():
  if value == 26:
    students_with_26_marks.append(name)
print("students_with_26_marks:",students_with_26_marks)
# Out:
# students_with_26_marks: ['shiva']

# %% [markdown]
# to add new element(key value ) in dictionary we use [""]=int
# example 3rd line in code

# %%
details= {"sai":3,"venky":4,"vishnu":6,"prashanti":9,"vyas":6,"yash":9,"uha":7}
print(details)
details["suma"] = 10
print(details)
print(type(details))
# Out:
# {'sai': 3, 'venky': 4, 'vishnu': 6, 'prashanti': 9, 'vyas': 6, 'yash': 9, 'uha': 7}
# {'sai': 3, 'venky': 4, 'vishnu': 6, 'prashanti': 9, 'vyas': 6, 'yash': 9, 'uha': 7, 'suma': 10}
# <class 'dict'>

# %% [markdown]
# **RANGE()**

# %% [markdown]
# ### `range()` with a step
# You can specify a step value in the `range()` function to control the increment between numbers. The syntax is `range(start, stop, step)`.

# %%
# Example of range with a step of 5
for i in range(0, 30, 5):
  print(i)
# Out:
# 0
# 5
# 10
# 15
# 20
# 25

# %%
distance= range(1,9)
print(distance)
for value in distance:
  print(value)
print(type(distance))
# Out:
# range(1, 9)
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# <class 'range'>

# %%
r=range(6)
print(r)
for value in r:
  print(value)
# Out:
# range(0, 6)
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# **DAY 7:**
# OPERATORS AND OPERANDS

# %% [markdown]
# **Arithematic Operators**

# %%
a=20
b=40
c=a+b
print("sum of a and b:",c)
# Out:
# sum of a and b: 60

# %%
a=10
b=5
c= (a+b)/(a-b)
print(c)
# Out:
# 3.0

# %%
a=8
b=2
print("sum:",a+b)
print("sub:",a-b)
print("mul:",a*b)
print("div:",a/b)
print("floor div:",a//b)
print("modulus:",a%b)
print("power:",a**b)
# Out:
# sum: 10
# sub: 6
# mul: 16
# div: 4.0
# floor div: 4
# modulus: 0
# power: 64

# %% [markdown]
# **Assignment Operators**

# %%
a= 6
print(a)
a+=2
print(a)
# Out:
# 6
# 8

# %%
x = 5
print(x)
x+=3
print(x)
x-=3
print(x)
x*=3
print(x)
x/=3
print(x)
x%=3
print(x)
x//=1
print(x)
x**=5
print(x)
# Out:
# 5
# 8
# 5
# 15
# 5.0
# 2.0
# 2.0
# 32.0

# %%
z = 10
print(z)
z %= 3  # This is equivalent to z = z % 3 (10 divided by 3 has a remainder of 1)
print(z)
# Out:
# 10
# 1

# %% [markdown]
# **Unary Minus Operator**

# %%
p=10
print(p)
print(-p)
# Out:
# 10
# -10

# %% [markdown]
# **Relational Operators**

# %%
x=3
y=5
z=3
print(x<y)
print(x>y)
print(x<=y)
print(x>=y)
print(x==z)
print(x!=y)
# Out:
# True
# False
# True
# False
# True
# True

# %%
a=10
b=15
print(b>a and a<b)
print(a>b and b>a)
print(a>b or b<a)
print(not a>b)
# Out:
# True
# False
# False
# True

# %% [markdown]
# **Membership Operators**

# %% [markdown]
# ### Membership Operator with Strings
# The `in` operator can also be used to check if a substring is present within a string.

# %%
x=(10,20,30,40,50,60,70)
print(22 in x)
print(22 not in x)
print(20 in x)
print(20 not in x)
# Out:
# False
# True
# True
# False

# %%
message = "Hello, how are you?"
print("how" in message)
print("hi" in message)
print("are" not in message)
# Out:
# True
# False
# False

# %% [markdown]
# **DAY 8 :**
# **Input and Outputs**

# %%
username = input("Enter the Username:")
password = input("Enter the Password:")
print("username:",username)
print("password:",password)
# Out:
# Enter the Username:yash@144
# Enter the Password:Rajarao
# username: yash@144
# password: Rajarao

# %%
name=  input("enter the name:")
age = input("enter the age:")
print("name entered as:",name)
print("age entered as:",age)
# Out:
# enter the name:yash
# enter the age:19
# name entered as: yash
# age entered as: 19

# %%
value1= input("enter the value:")
value2= input("enter the value:")
print(value1+value2)
# Out:
# enter the value:1
# enter the value:1
# 11

# %% [markdown]
# **converting string to integer**

# %%
#lets convert string to integer
a= input("enter the value:")
b=input("enter the value:")
c=a+b
print("sum:",c)
print(type(c))
#converting
x=int(a)
y=int(b)
z=x+y
print("sum:",z)
print(type(z))
# Out:
# enter the value:a
# enter the value:b
# sum: ab
# <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1160349498.py in <cell line: 0>()
#       6 print(type(c))
#       7 #converting
# ----> 8 x=int(a)
#       9 y=int(b)
#      10 z=x+y
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
a= input("enter the value of a:")
b= input("enter the value of b:")
print(a+b)
print(type(a))
#converting
x=int(a)
y=int(b)
z= x+y
print("sum of x and y are:",x+y)
print(type(z))
# Out:
# enter the value of a:4
# enter the value of b:4
# 44
# <class 'str'>
# sum of x and y are: 8
# <class 'int'>

# %%
v= input("enter the value:")
v1= input("enter the value:")
vt= v+v1
print("sum:",vt)
f=float(v)
f1=float(v1)
ft=f+f1
print("after conversion into float")
print("sum:",ft)
# Out:
# enter the value:5.6
# enter the value:6.6
# sum: 5.66.6
# after conversion into float
# sum: 12.2

# %%
a=input("enter the value of a:")
b=input("enter the value of b:")
print(type(a))
f=float(a)
f1=float(b)
print("value:",f+f1)
print(type(f1+f))
# Out:
# enter the value of a:23
# enter the value of b:21
# <class 'str'>
# value: 44.0
# <class 'float'>

# %%
a=20.4
print(type(a))
b=int(a)
print(b)
print(type(b))
# Out:
# <class 'float'>
# 20
# <class 'int'>

# %% [markdown]
# **Flow Control**
#
# 1. sequential statements (executes simple programs)

# %%
print("yash")
print("sai")
print("vyas")
# Out:
# yash
# sai
# vyas

# %%
print(1)
print(2)
print(3)
print("@four")
# Out:
# 1
# 2
# 3
# @four

# %% [markdown]
# 2. Conditional Statements (executes better and cimplex programs)

# %%
print("hii")
print("bye")
# Out:
# hii
# bye

# %% [markdown]
# **conditional statements**

# %%
a=10
b=20
if a<b:
  print("yes")
# Out:
# yes

# %%
my_list = [10, 20, 30, 40, 50]

if 30 in my_list:
  print("30 is present in the list.")

if 60 not in my_list:
  print("60 is not present in the list.")
# Out:
# 30 is present in the list.
# 60 is not present in the list.

# %%
a=input("enter a value:")
b=input("enter b value:")
x=int(a)
y=int(b)
if x<y:
  print("x is smaller than y")
if x>y:
  print("x is bigger than y")
# Out:
# enter a value:44
# enter b value:77
# x is smaller than y

# %%
x=10
y=10.1
if x>y:
  print("x is big")
else:
  print("y is big")
# Out:
# y is big

# %%
name=input("enter the name:")
if name == "yash" :
  print("fee paid")
else:
  print("fee not paid")
# Out:
# enter the name:vyas
# fee not paid

# %%
names=["yash","sai","vishnu","prashanti","pallavi","sanjana","suma","sunayana"]
names.append("prem")
name= input("enter the name:")
if name in names:
  print("fee paid")
else:
  print("fee not paid")
# Out:
# enter the name:prem
# fee paid

# %%
marks= int(input("enter the marks:"))
if marks>=90:
  print("grade A")
elif marks >=80:
  print("grade B")
elif marks >=50:
  print("grade C")
else:
  print("fail")
# Out:
# enter the marks:29
# fail

# %%
a = int(input("enter the values:"))
if a == 0:
  print("enterd 0")
elif a==1:
  print("entered 1")
elif a==2:
  print("entered 2")
elif a==3:
  print("enter 3")
else:
  print("beyond the range specified")
# Out:
# enter the values:3
# enter 3

# %% [markdown]
# **looping statements**

# %%
marks = [10,15,20,25,30]
for values in marks:
  print(values)
# Out:
# 10
# 15
# 20
# 25
# 30

# %% [markdown]
# ### More Complex `for` loop Example
#
# This example uses a `for` loop to process a list of student dictionaries. For each student, it checks their `score`. If the score is 60 or higher, it prints a 'Pass' message; otherwise, it prints 'Fail'.

# %%
students = [
    {"name": "Alice", "score": 85},
    {"name": "Bob", "score": 55},
    {"name": "Charlie", "score": 70},
    {"name": "Diana", "score": 40}
]

print("--- Student Performance ---")
for student in students:
  name = student["name"]
  score = student["score"]

  if score >= 60:
    print(f"{name} passed with a score of {score}.")
  else:
    print(f"{name} failed with a score of {score}.")
print("---------------------------")
# Out:
# --- Student Performance ---
# Alice passed with a score of 85.
# Bob failed with a score of 55.
# Charlie passed with a score of 70.
# Diana failed with a score of 40.
# ---------------------------

# %%
numbers = [10, 20, 30, 40, 50]
total_sum = 0

for number in numbers:
  total_sum += number   #total suum= total sum+number
print("The sum of the numbers in the list is:", total_sum)
# Out:
# The sum of the numbers in the list is: 150

# %%
numbers = [10, 20, 30, 40, 50]
total_sum = 0
for number in numbers:
  total_sum += number # This is equivalent to total_sum = total_sum + number

print("The sum of the numbers in the list is:", total_sum)
# Out:
# The sum of the numbers in the list is: 150

# %%
marks = [1,2,3,4,5]
t_marks = 0
for mark in marks :
  t_marks +=mark
print("total marks:",t_marks)
# Out:
# total marks: 15

# %%
value = input("enter a value:")
print(type(value))
# Out:
# enter a value:2
# <class 'str'>

# %%
Age = 20
print(Age)
# Out:
# 20

# %%
student_info = {"yash":29}
student_section = "a"
print(student_info,student_section)
# Out:
# {'yash': 29} a

# %%
name,marks,number= "yash",25,29
print(name,marks,number)
# Out:
# yash 25 29

# %%
x=y=z=50
print(x,y,z)
# Out:
# 50 50 50

# %%
emp1= "yash"
print(emp1)
# Out:
# yash

# %%
Pcost = 345.60
ordered = 3
s_charge = 20
tip = 30
bill_amount = Pcost*3+s_charge+tip
print(bill_amount)
# Out:
# 1086.8000000000002

# %% [markdown]
# FUNCTIONS

# %%
#user defined functions
def laptop():
  print("this is a device")

laptop()
# Out:
# this is a device

# %%
def add(a,b):
  c= a+b
  print(c)
add(3,4)
# Out:
# 7

# %%
def student(name,marks):
  print("name:",name)
  print("mark:",marks)
student('yash',50)
student('sai',45)
student('suma',44)
# Out:
# name: yash
# mark: 50
# name: sai
# mark: 45
# name: suma
# mark: 44

# %%
def grade(v):
  print("hii")
grade(2)
# Out:
# hii

# %%
#callig two functions
def func1():
  print("yash")
def func2():
  print("naidu")
func1()
func2()
# Out:
# yash
# naidu

# %%
#calling functin1 in function2
def fun1():
  print("hello")


def fun2():
  print("world")
  fun1()

fun2()
# Out:
# world
# hello

# %%
def testing(a):
  print("one parameterised function:", a)
x = input("Enter a value:")
testing(x)
# Out:
# Enter a value:hii
# one parameterised function: hii

# %%
u=10
v=20
print("u,v,a,b,c,d all are variables")
def new(a,b):
  print(a+b)
c = int(input("enter:"))
d= int(input("enter:"))
new(c,d)
new(10,33)
# Out:
# u,v,a,b,c,d all are variables
# enter:6
# enter:4
# 10
# 43

# %%
def amount():
  print("amount is secure")
  return 100
b=amount()
print(b)
# Out:
# amount is secure
# 100
